# %%
import numpy as np

# %%
from matplotlib import pyplot as plt 
#for ploting of graph

# %%
from scipy.integrate import solve_ivp
#for calculation of ode and integrating numericals

# %%
from scipy.special import factorial

# %%
x = np.linspace(-10,10,2000)#will genrate 2000 numbers between -10 and 10 with a equal spacing and -10 and 10 will alaways be included in form of matrix
y  = np.sin(x)
plt.plot(x,y,'k',linewidth = 2)
plt.xlim = (-10,10)
plt.ylim = (-10,10)
plt.grid(True)
